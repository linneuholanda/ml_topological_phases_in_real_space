# %% [markdown]
# # Analyzing simulation data

# %%
from IPython.core.display import HTML
HTML("<script>Jupyter.notebook.kernel.restart()</script>")
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from prediction_grids3 import *

# %% [markdown]
# ## Testing Experiment class

# %%
simulation_dir = "./simulation/fig1b-6561-100"
experiment_name = "0"
experiment = Experiment(simulation_dir, experiment_name)

# %% [markdown]
# #### Viewing Train/Val/Test split

# %%
experiment.print_train_val_test()
# Out:
# % train:  0.4208199969516842
# % val:  0.42066758116140834
# % test:  0.15851242188690748
# % train + val + test:  1.0
#
#
# number of train hamiltonians:  2761
# number of val hamiltonians:  2760
# number of test hamiltonians:  1040
# total number of hamiltonians:  6561

# %% [markdown]
# #### Viewing data set summary

# %%
experiment.print_phases()
# Out:
# Summary of train + val data
#
# % train/val phases:
#  0    0.325122
#  1    0.322586
# -1    0.178953
#  2    0.173338
# Name: phase, dtype: float64
#
#
# total train/val phases:
#  0    1795
#  1    1781
# -1     988
#  2     957
# Name: phase, dtype: int64
#
#
# Summary of test data
#
# % test phases:
#  2    0.399302
# -1    0.363213
#  1    0.126892
#  0    0.110594
# Name: phase, dtype: float64
#
#
# total test phases:
#  2    343
# -1    312
#  1    109
#  0     95
# Name: phase, dtype: int64
#
#
# Summary of train + val + test data
#
# % phases:
#  1    0.296238
#  0    0.296238
# -1    0.203762
#  2    0.203762
# Name: phase, dtype: float64
#
#
# total phases:
#  1    1890
#  0    1890
# -1    1300
#  2    1300
# Name: phase, dtype: int64

# %% [markdown]
# #### Viewing eigenvector summary

# %%
experiment.eigenvector_summary.head()
# Out:
#    id  phase  pred_phase type_of
# 0   0    999          -1    test
# 1   0    999          -1    test
# 2   0    999          -1    test
# 3   0    999          -1    test
# 4   0    999          -1    test

# %% [markdown]
# #### Viewing hamiltonian summary

# %%
experiment.hamiltonian_summary.head()
# Out:
#      t1    t2 type_of    -1     0     1     2  phase  pred_phase
# id
# 0  -2.0 -2.00    test  0.20  0.50  0.29  0.01    999           0
# 1  -2.0 -1.95    test  0.23  0.55  0.21  0.01     -1           0
# 2  -2.0 -1.90    test  0.24  0.47  0.27  0.02     -1           0
# 3  -2.0 -1.85    test  0.25  0.38  0.32  0.05     -1           0
# 4  -2.0 -1.80    test  0.24  0.38  0.35  0.03     -1           0

# %% [markdown]
# #### Viewing accuracy

# %%
experiment.accuracy
# Out:
# {'eigenvector_train': 0.9998080405650127,
#  'eigenvector_val': 0.9707717391304348,
#  'eigenvector_test': 0.670861466821886,
#  'hamiltonian_train': 1.0,
#  'hamiltonian_val': 0.9963768115942029,
#  'hamiltonian_test': 0.8684516880093132}

# %% [markdown]
# #### Visualizing train/val/test splits with scatter plot

# %%
#fig_params={"figsize": (8,6)} 
fig_params = fig_params={"figsize": (6,6)} 
#val_params={"marker": "s", "s": 64, "alpha": 0.2, "color": "salmon", "label": "val"}
#test_params={"marker": "s", "s": 64, "alpha": 0.2, "color": "blue", "label": "test"}
#train_params={"marker": "o", "s": 10, "color": "red", "label": "train"}
val_params={"marker": "s", "s": 64, "alpha": 0.2, "color": "salmon", "label": "val"}
test_params={"marker": "s", "s": 64, "alpha": 0.5, "color": "royalblue", "label": "test"}
train_params={"marker": "o", "s": 3, "alpha": 1, "color": "green", "label": "train"}
legend_params={"framealpha": 0.8, "loc": "upper right", "fontsize": 16}
xlabel_params={"xlabel": "$t_2$", "fontsize": 24}
ylabel_params={"ylabel": "$t_1$", "fontsize": 24}
title_params={}
xlim_params = {"left": np.min(experiment.t2), "right": np.max(experiment.t2)}
ylim_params = {"bottom": np.min(experiment.t1), "top": np.max(experiment.t1)}
xticks_params = {"fontsize": 14}
yticks_params = {"fontsize": 14}
tight_params = {}
#savefig_params = {"fname": os.path.join(experiment.simulation_dir, "fig1a-6561_train_val_test_0.png")}
path_to_save = "/home/linneu/Dropbox/Machine/paper_submissions/arxiv3/fig1b-6561-100-train_val_test_0.png"
savefig_params = {"fname": path_to_save}
experiment.scatter_train_val_test(val_params, test_params, train_params, legend_params, fig_params, xlabel_params, \
                               ylabel_params, title_params, xlim_params, ylim_params, xticks_params, yticks_params,\
                                 tight_params, savefig_params)

# %% [markdown]
# #### Plotting train winding labels with scatter plot.

# %%
#fig_params={"figsize": (8,6)} 
fig_params = fig_params={"figsize": (6,6)} 
winding_params = {-1: {"marker": "o", "s": 10, "color": "red", "label": -1}, 
                  0: {"marker": "o", "s": 10, "color": "darkorange", "label": 0}, \
                  1: {"marker": "o", "s": 10, "color": "green", "label": 1}, \
                  2: {"marker": "o", "s": 10, "color": "blue", "label": 2}}
legend_params={"framealpha": 0.8, "loc": "upper right", "fontsize": 16}
xlabel_params={"xlabel": "$t_2$", "fontsize": 24}
ylabel_params={"ylabel": "$t_1$", "fontsize": 24}
title_params={}
xlim_params = {"left": np.min(experiment.t2), "right": np.max(experiment.t2)}
ylim_params = {"bottom": np.min(experiment.t1), "top": np.max(experiment.t1)}
xticks_params = {"fontsize": 14}
yticks_params = {"fontsize": 14}
tight_params = {}
path_to_save = "/home/linneu/Dropbox/Machine/paper_submissions/arxiv3/fig1b-6561-100-train_winding_labels_0.png"
savefig_params = {"fname": path_to_save}
experiment.scatter_winding_train(winding_params, legend_params, fig_params, xlabel_params, ylabel_params, \
                                 title_params,  xlim_params, ylim_params, xticks_params, yticks_params, \
                                 tight_params, savefig_params)

# %% [markdown]
# #### Plotting prediction grid with pcolormesh

# %%
#fig_params, winding_params, contourf_params, legend_params, xlabel_params, ylabel_params, title_params, savefig_params)
#fig_params={"figsize": (8,6)} 
fig_params = fig_params={"figsize": (6,6)}
#winding_params = {0: {"marker": "o", "s": 10, "color": "darkorange", "label": 0}, -1: {"marker": "o", "s": 10, "color": "red", "label": -1}, \
#                  2: {"marker": "o", "s": 10, "color": "blue", "label": 2}, \
#                  1: {"marker": "o", "s": 10, "color": "green", "label": 1}}
winding_params = {-1: {"marker": "o", "s": 10, "color": "red", "label": -1}, 
                  0: {"marker": "o", "s": 10, "color": "darkorange", "label": 0}, \
                  1: {"marker": "o", "s": 10, "color": "green", "label": 1}, \
                  2: {"marker": "o", "s": 10, "color": "blue", "label": 2}}
pcolormesh_params = {"cmap": ListedColormap(["hotpink", "orange", "lightgreen","lightskyblue"]), "alpha": 0.5}
legend_params={"framealpha": 0.8, "loc": "upper right", "fontsize": 16}
xlabel_params={"xlabel": "$t_2$", "fontsize": 24}
ylabel_params={"ylabel": "$t_1$", "fontsize": 24}
title_params={}
xlim_params = {"left": np.min(experiment.t2), "right": np.max(experiment.t2)}
ylim_params = {"bottom": np.min(experiment.t1), "top": np.max(experiment.t1)}
xticks_params = {"fontsize": 14}
yticks_params = {"fontsize": 14}
tight_params = {}
path_to_save = "/home/linneu/Dropbox/Machine/paper_submissions/arxiv3/fig1b-6561-100-prediction_grid_0.png"
savefig_params = {"fname": os.path.join(experiment.simulation_dir, path_to_save)}
experiment.pcolormesh_prediction_grid(winding_params, pcolormesh_params, legend_params, fig_params, xlabel_params, \
                                ylabel_params, title_params, xlim_params, ylim_params, xticks_params, yticks_params, \
                                      tight_params,  savefig_params)

# %% [markdown]
# #### Plotting Winding heatmaps

# %%
winding = 1
imshow_params = {"cmap": "Greens", "aspect": "equal", "alpha": 1, "origin": "lower", "extent": [-2,2,-2,2], "vmin": 0, "vmax": 1}
colorbar_params=colorbar_params={"mappable": None, "ticks": np.linspace(0,1,6), "orientation": "vertical", \
                                 "pad": 0.1, "shrink": 0.8, "labelsize": 24}
##########
fig_params = fig_params={"figsize": (12,12)}
xlabel_params={"xlabel": "$t_2$", "fontsize": 48}
ylabel_params={"ylabel": "$t_1$", "fontsize": 48}
title_params={}
xlim_params = {"left": np.min(experiment.t2), "right": np.max(experiment.t2)}
ylim_params = {"bottom": np.min(experiment.t1), "top": np.max(experiment.t1)}
xticks_params = {"fontsize": 24}
yticks_params = {"fontsize": 24}
tight_params={}
path_to_save = "/home/linneu/Dropbox/Machine/paper_linneu/fig1b-6561-100-winding_grid_2.png"
savefig_params = {"fname": path_to_save}
experiment.imshow_winding_grid(winding, imshow_params, colorbar_params, fig_params, xlabel_params, \
                               ylabel_params, title_params, xlim_params, ylim_params, xticks_params, yticks_params, \
                               tight_params, savefig_params)

# %%
###Reds_alpha
ncolors = 256
color_array = plt.get_cmap('Reds')(range(ncolors))
# change alpha values
color_array[:,-1] = np.linspace(0.0,1.0,ncolors)
# create a colormap object
map_object = LinearSegmentedColormap.from_list(name='Reds_alpha',colors=color_array)
plt.register_cmap(cmap=map_object)


###Oranges_alpha
ncolors = 256
color_array = plt.get_cmap('Oranges')(range(ncolors))
# change alpha values
color_array[:,-1] = np.linspace(0.0,1.0,ncolors)
# create a colormap object
map_object = LinearSegmentedColormap.from_list(name='Oranges_alpha',colors=color_array)
plt.register_cmap(cmap=map_object)


### Greens_alpha
ncolors = 256
color_array = plt.get_cmap('Greens')(range(ncolors))
# change alpha values
color_array[:,-1] = np.linspace(0.0,1.0,ncolors)
# create a colormap object
map_object = LinearSegmentedColormap.from_list(name='Greens_alpha',colors=color_array)
plt.register_cmap(cmap=map_object)

### Blues_alpha
ncolors = 256
color_array = plt.get_cmap('Blues')(range(ncolors))
# change alpha values
color_array[:,-1] = np.linspace(0.0,1.0,ncolors)
# create a colormap object
map_object = LinearSegmentedColormap.from_list(name='Blues_alpha',colors=color_array)
plt.register_cmap(cmap=map_object)




#########################################################################################
#winding = 2
#imshow_params = {"cmap": "Blues_alpha", "aspect": "equal", "alpha": 1, "origin": "lower", "extent": [-2,2,-2,2]}
#colorbar_params={}
##########
#fig_params = fig_params={"figsize": (8,8)}
#xlabel_params={"xlabel": "$t_2$", "fontsize": 18}
#ylabel_params={"ylabel": "$t_1$", "fontsize": 18}
#title_params={}
#path_to_save = "/home/linneu/Dropbox/Machine/paper_linneu/fig1b-6561-100-winding_grid_0_test_alpha.png"
#savefig_params = {"fname": path_to_save}
#savefig_params = {}
#experiment.imshow_winding_grid(winding, imshow_params, colorbar_params, fig_params, xlabel_params, \
#                               ylabel_params, title_params, savefig_params)

# %% [markdown]
# #### Plotting merged winding heatmaps

# %%
winding_params = {-1: {"cmap": "Reds_alpha", "aspect": "equal", "alpha": 1, "origin": "lower", "extent": [-2,2,-2,2], \
                  "vmin": 0, "vmax": 1},
                 0: {"cmap": "Oranges_alpha", "aspect": "equal", "alpha": 1, "origin": "lower", "extent": [-2,2,-2,2], \
                     "vmin": 0, "vmax": 1},
                 1: {"cmap": "Greens_alpha", "aspect": "equal", "alpha": 1, "origin": "lower", "extent": [-2,2,-2,2], \
                     "vmin": 0, "vmax": 1},
                 2: {"cmap": "Blues_alpha", "aspect": "equal", "alpha": 1, "origin": "lower", "extent": [-2,2,-2,2],\
                  "vmin": 0, "vmax": 1}}
colorbar_params={}
##########
fig_params = {"figsize": (8,8)}
xlabel_params={"xlabel": "$t_2$", "fontsize": 18}
ylabel_params={"ylabel": "$t_1$", "fontsize": 18}
title_params={}
xlim_params = {"left": np.min(experiment.t2), "right": np.max(experiment.t2)}
ylim_params = {"bottom": np.min(experiment.t1), "top": np.max(experiment.t1)}
xticks_params = {}
yticks_params = {}
tight_params = {}
path_to_save = "/home/linneu/Dropbox/Machine/paper_linneu/fig1b-6561-100-merged_winding_grid_0.png"
savefig_params = {"fname": path_to_save}
experiment.merge_imshow_winding_grids(winding_params, colorbar_params, fig_params, xlabel_params, ylabel_params, \
                                      title_params, xlim_params, ylim_params, xticks_params, yticks_params,  \
                                      tight_params, savefig_params)

# %% [markdown]
# ## Testing Simulation Class

# %%
simulation_name = "fig1b-6561-100"
n_experiments = None
load_hamiltonian_summary = False
simulation = Simulation(simulation_name, n_experiments, load_hamiltonian_summary)

# %% [markdown]
# #### Computing Hamiltonian summary

# %%
simulation.compute_hamiltonian_summary()
# Out:
# mean hamiltonian summary: 100%|██████████| 100/100 [00:01<00:00, 62.57it/s]
# majority vote: 100%|██████████| 6561/6561 [00:00<00:00, 28281.09it/s]

# %%
simulation.hamiltonian_summary
# Out:
#        t1    t2 type_of      -1       0       1       2  phase  pred_phase
# id
# 0    -2.0 -2.00    test  0.2131  0.4736  0.2724  0.0409    999           0
# 1    -2.0 -1.95    test  0.2171  0.4924  0.2577  0.0328     -1           0
# 2    -2.0 -1.90    test  0.2182  0.4680  0.2834  0.0304     -1           0
# 3    -2.0 -1.85    test  0.2448  0.3972  0.3271  0.0309     -1           0
# 4    -2.0 -1.80    test  0.2444  0.4076  0.3277  0.0203     -1           0
# 5    -2.0 -1.75    test  0.2527  0.4271  0.3032  0.0170     -1           0
# 6    -2.0 -1.70    test  0.2744  0.4126  0.2923  0.0207     -1           0
# 7    -2.0 -1.65    test  0.2993  0.3781  0.3020  0.0206     -1           0
# 8    -2.0 -1.60    test  0.3375  0.3454  0.2910  0.0261     -1           0
# 9    -2.0 -1.55    test  0.3893  0.2731  0.3114  0.0262     -1          -1
# 10   -2.0 -1.50    test  0.4495  0.2460  0.2687  0.0358     -1          -1
# 11   -2.0 -1.45    test  0.5182  0.2185  0.2224  0.0409     -1          -1
# 12   -2.0 -1.40    test  0.5993  0.1599  0.2022  0.0386     -1          -1
# 13   -2.0 -1.35   train  0.8014  0.0764  0.1057  0.0165     -1          -1
# 14   -2.0 -1.30     val  0.8795  0.0527  0.0574  0.0104     -1          -1
# 15   -2.0 -1.25   train  0.9355  0.0251  0.0331  0.0063     -1          -1
# 16   -2.0 -1.20     val  0.9349  0.0148  0.0254  0.0249     -1          -1
# 17   -2.0 -1.15   train  0.9649  0.0061  0.0199  0.0091     -1          -1
# 18   -2.0 -1.10     val  0.9685  0.0045  0.0207  0.0063     -1          -1
# 19   -2.0 -1.05   train  0.9706  0.0111  0.0177  0.0006     -1          -1
# 20   -2.0 -1.00     val  0.9813  0.0039  0.0148  0.0000     -1          -1
# 21   -2.0 -0.95   train  0.9860  0.0042  0.0098  0.0000     -1          -1
# 22   -2.0 -0.90   train  0.9872  0.0088  0.0040  0.0000     -1          -1
# 23   -2.0 -0.85     val  0.9935  0.0016  0.0049  0.0000     -1          -1
# 24   -2.0 -0.80   train  0.9932  0.0041  0.0027  0.0000     -1          -1
# 25   -2.0 -0.75   train  0.9790  0.0078  0.0121  0.0011     -1          -1
# 26   -2.0 -0.70   train  0.9896  0.0039  0.0065  0.0000     -1          -1
# 27   -2.0 -0.65     val  0.9950  0.0032  0.0016  0.0002     -1          -1
# 28   -2.0 -0.60     val  0.9959  0.0041  0.0000  0.0000     -1          -1
# 29   -2.0 -0.55   train  0.9971  0.0020  0.0007  0.0002     -1          -1
# ...   ...   ...     ...     ...     ...     ...     ...    ...         ...
# 6531  2.0  0.55     val  0.9936  0.0057  0.0007  0.0000     -1          -1
# 6532  2.0  0.60     val  0.9948  0.0049  0.0002  0.0001     -1          -1
# 6533  2.0  0.65   train  0.9948  0.0051  0.0001  0.0000     -1          -1
# 6534  2.0  0.70   train  0.9938  0.0061  0.0001  0.0000     -1          -1
# 6535  2.0  0.75   train  0.9913  0.0072  0.0011  0.0004     -1          -1
# 6536  2.0  0.80   train  0.9989  0.0011  0.0000  0.0000     -1          -1
# 6537  2.0  0.85     val  0.9973  0.0023  0.0001  0.0003     -1          -1
# 6538  2.0  0.90   train  0.9944  0.0042  0.0004  0.0010     -1          -1
# 6539  2.0  0.95     val  0.9954  0.0033  0.0000  0.0013     -1          -1
# 6540  2.0  1.00   train  0.9962  0.0026  0.0000  0.0012     -1          -1
# 6541  2.0  1.05   train  0.9932  0.0064  0.0001  0.0003     -1          -1
# 6542  2.0  1.10   train  0.9976  0.0014  0.0005  0.0005     -1          -1
# 6543  2.0  1.15   train  0.9951  0.0024  0.0005  0.0020     -1          -1
# 6544  2.0  1.20     val  0.9982  0.0006  0.0008  0.0004     -1          -1
# 6545  2.0  1.25     val  0.9977  0.0020  0.0000  0.0003     -1          -1
# 6546  2.0  1.30     val  0.9960  0.0036  0.0001  0.0003     -1          -1
# 6547  2.0  1.35     val  0.9959  0.0020  0.0006  0.0015     -1          -1
# 6548  2.0  1.40   train  0.9941  0.0028  0.0002  0.0029     -1          -1
# 6549  2.0  1.45   train  0.9852  0.0034  0.0032  0.0082     -1          -1
# 6550  2.0  1.50   train  0.9696  0.0083  0.0083  0.0138     -1          -1
# 6551  2.0  1.55     val  0.9182  0.0397  0.0096  0.0325     -1          -1
# 6552  2.0  1.60    test  0.7416  0.1205  0.0344  0.1035     -1          -1
# 6553  2.0  1.65    test  0.6149  0.1536  0.0403  0.1912     -1          -1
# 6554  2.0  1.70    test  0.5334  0.1797  0.0582  0.2287     -1          -1
# 6555  2.0  1.75    test  0.4885  0.1900  0.0530  0.2685     -1          -1
# 6556  2.0  1.80    test  0.4529  0.1826  0.0623  0.3022     -1          -1
# 6557  2.0  1.85    test  0.3883  0.1880  0.0907  0.3330     -1          -1
# 6558  2.0  1.90    test  0.3130  0.2108  0.1208  0.3554     -1           2
# 6559  2.0  1.95    test  0.2566  0.2576  0.1156  0.3702     -1           2
# 6560  2.0  2.00    test  0.2339  0.2794  0.1132  0.3735    999           2
#
# [6561 rows x 9 columns]

# %% [markdown]
# #### Plotting simulation winding heatmaps

# %%
winding = 2
imshow_params = {"cmap": "Blues", "aspect": "equal", "alpha": 1, "origin": "lower", "extent": [-2,2,-2,2], "vmin": 0, "vmax": 1}
colorbar_params=colorbar_params={"mappable": None, "ticks": np.linspace(0,1,6), "orientation": "vertical", \
                                 "pad": 0.1, "shrink": 0.8}
##########
fig_params = fig_params={"figsize": (8,8)}
xlabel_params={"xlabel": "$t_2$", "fontsize": 18}
ylabel_params={"ylabel": "$t_1$", "fontsize": 18}
title_params={}
xlim_params = {"left": np.min(experiment.t2), "right": np.max(experiment.t2)}
ylim_params = {"bottom": np.min(experiment.t1), "top": np.max(experiment.t1)}
xticks_params = {}
yticks_params = {}
path_to_save = "/home/linneu/Dropbox/Machine/paper_linneu/fig1b-441_simulation_winding_grid_blue.png"
savefig_params = {"fname": path_to_save}
tight_params = {}
#experiment.imshow_winding_grid(winding, imshow_params, colorbar_params, fig_params, xlabel_params, \
#                               ylabel_params, title_params, savefig_params)
experiment.imshow_winding_grid(winding, imshow_params, colorbar_params, fig_params, xlabel_params, \
                               ylabel_params, title_params, xlim_params, ylim_params, xticks_params, yticks_params, \
                               tight_params, savefig_params)

# %% [markdown]
# #### Plotting simulation merged winding heatmaps

# %%
winding_params = {-1: {"cmap": "Reds_alpha", "aspect": "equal", "alpha": 1, "origin": "lower", "extent": [-2,2,-2,2], \
                  "vmin": 0, "vmax": 1},
                 0: {"cmap": "Oranges_alpha", "aspect": "equal", "alpha": 1, "origin": "lower", "extent": [-2,2,-2,2], \
                     "vmin": 0, "vmax": 1},
                 1: {"cmap": "Greens_alpha", "aspect": "equal", "alpha": 1, "origin": "lower", "extent": [-2,2,-2,2], \
                     "vmin": 0, "vmax": 1},
                 2: {"cmap": "Blues_alpha", "aspect": "equal", "alpha": 1, "origin": "lower", "extent": [-2,2,-2,2],\
                  "vmin": 0, "vmax": 1}}
#colorbar_params={"mappable": None}
colorbar_params={}
##########
fig_params = {"figsize": (12,12)}
xlabel_params={"xlabel": "$t_2$", "fontsize": 48}
ylabel_params={"ylabel": "$t_1$", "fontsize": 48}
title_params={}
xlim_params = {"left": np.min(experiment.t2), "right": np.max(experiment.t2)}
ylim_params = {"bottom": np.min(experiment.t1), "top": np.max(experiment.t1)}
xticks_params = {"fontsize": 24}
yticks_params = {"fontsize": 24}
tight_params={}
path_to_save = "/home/linneu/Dropbox/Machine/paper_submissions/arxiv3/fig1b-6561-100-simulation_merged_winding_grid.png"
savefig_params = {"fname": path_to_save}
simulation.merge_imshow_winding_grids(winding_params, colorbar_params, fig_params, xlabel_params, ylabel_params, \
                                      title_params, xlim_params, ylim_params, xticks_params, yticks_params,  \
                                      tight_params, savefig_params)
# Out:
# Plotting winding -1
# Plotting winding 0
# Plotting winding 1
# Plotting winding 2

# %% [markdown]
# #### Computing mean accuracies

# %%
save_to_disk = True
simulation.compute_mean_accuracy(save_to_disk)
# Out:
# computing mean accuracies: 100%|██████████| 100/100 [16:36<00:00, 32.09s/it]

# %%
simulation.mean_accuracy
# Out:
# {'eigenvector_train': 0.9997201014125318,
#  'eigenvector_val': 0.9733354347826086,
#  'eigenvector_test': 0.6781416763678696,
#  'hamiltonian_train': 1.0,
#  'hamiltonian_val': 0.9972391304347826,
#  'hamiltonian_test': 0.8821187427240977}

# %% [markdown]
# #### Computing bootstrap accuracies

# %%
save_to_disk = True
simulation.compute_bootstrap_accuracy(save_to_disk)

# %%
simulation.bootstrap_accuracy
# Out:
# {'hamiltonian_train': 1.0,
#  'hamiltonian_val': 1.0,
#  'hamiltonian_test': 0.8940628637951106}

# %% [markdown]
# #### Plotting simulation merged winding heatmaps

# %%
winding_params = {-1: {"cmap": "Reds", "aspect": "equal", "alpha": 0.05, "origin": "lower", "extent": [-2,2,-2,2]}, \
                 0: {"cmap": "Oranges", "aspect": "equal", "alpha": 0.05, "origin": "lower", "extent": [-2,2,-2,2]}, \
                 1: {"cmap": "Greens", "aspect": "equal", "alpha": 0.05, "origin": "lower", "extent": [-2,2,-2,2]}, \
                 2: {"cmap": "Blues", "aspect": "equal", "alpha": 0.05, "origin": "lower", "extent": [-2,2,-2,2]}}
colorbar_params={}
##########
fig_params = {"figsize": (8,8)}
xlabel_params={"xlabel": "$t_2$", "fontsize": 18}
ylabel_params={"ylabel": "$t_1$", "fontsize": 18}
title_params={}
path_to_save = "/home/linneu/Dropbox/Machine/paper_linneu/fig1b-441_winding_grid_0.png"
savefig_params = {"fname": path_to_save}
simulation.merge_imshow_winding_grids(winding_params, colorbar_params, fig_params, xlabel_params, ylabel_params, \
                                      title_params, savefig_params)
# Out:
# merged imshow winding grid: 100%|██████████| 30/30 [00:01<00:00, 22.12it/s]

# %% [markdown]
# #### Computing statistics

# %%
simulation.compute_statistics()
# Out:
# computing statistics: 100%|██████████| 30/30 [01:17<00:00,  2.28s/it]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-7008e24defbf> in <module>
# ----> 1 simulation.compute_statistics()
#
# ~/Dropbox/notebooks/topological_phase/fig1b-441/prediction_grids3.py in compute_statistics(self)
#     338             self.popular_vote.loc[:,self.allowed_windings_str] += 1/self.n_experiments*current_exp.hamiltonian_summary.loc[:,self.allowed_windings_str]
#     339         ### majority vote for self.popular_vote
# --> 340         votes_array = self.popular_vote[:,self.allowed_windings_str].values
#     341         max_values = np.max(votes_array, axis = 1).reshape((-1,1))
#     342         boolean_max = np.equal(votes_array, max_values)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2485         """Return the cached item, item represents a label indexer."""
#    2486         cache = self._item_cache
# -> 2487         res = cache.get(item)
#    2488         if res is None:
#    2489             values = self._data.get(item)
#
# TypeError: unhashable type: 'slice'

# %% [markdown]
# #### Plotting contourf prediction grid

# %%
winding_params = {-1: {"cmap": "Reds_alpha", "aspect": "equal", "alpha": 1, "origin": "lower", "extent": [-2,2,-2,2]}, \
                 0: {"cmap": "Oranges_alpha", "aspect": "equal", "alpha": 1, "origin": "lower", "extent": [-2,2,-2,2]}, \
                 1: {"cmap": "Greens_alpha", "aspect": "equal", "alpha": 1, "origin": "lower", "extent": [-2,2,-2,2]}, \
                 2: {"cmap": "Blues_alpha", "aspect": "equal", "alpha": 1, "origin": "lower", "extent": [-2,2,-2,2]}}

##########
legend_params = {}
fig_params = fig_params={"figsize": (8,8)}
xlabel_params={"xlabel": "$t_2$", "fontsize": 18}
ylabel_params={"ylabel": "$t_1$", "fontsize": 18}
title_params={}
path_to_save = "/home/linneu/Dropbox/Machine/paper_linneu/fig1b-6561-100_contourf_grid_0.png"
savefig_params = {"fname": path_to_save}
experiment.contourf_prediction_grid(winding_params, legend_params, fig_params, xlabel_params, ylabel_params, title_params, savefig_params)

# %%
simulation.mean_accuracy
# Out:
# defaultdict(int,
#             {'eigenvector_train': 0.9814616726618693,
#              'eigenvector_val': 0.9624534559999998,
#              'eigenvector_test': 0.778809526066351,
#              'hamiltonian_train': 1.0000000000000007,
#              'hamiltonian_val': 1.0000000000000007,
#              'hamiltonian_test': 0.9914703791469197})

# %%
experiment.xx
# Out:
# array([[-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ],
#        [-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ],
#        [-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ],
#        [-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ],
#        [-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ],
#        [-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ],
#        [-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ],
#        [-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ],
#        [-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ],
#        [-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ],
#        [-2. , -1.6, -1.2, -0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ]])

# %%
self.
