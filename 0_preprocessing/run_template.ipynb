# %% [markdown]
# # Running template
# This notebook runs the template notebook `preprocessing_template.ipynb` for both ssh1 and ssh2 grids.

# %%
import papermill as pm
from tqdm import tqdm

# %% [markdown]
# ## SSH 1

# %%
template = "preprocessing_template.ipynb"
parameters = {"allowed_windings":[0,1], "epsilon":0.01, "to_csv":True}
kernel_name = "ml_top_phases"

# %% [markdown]
# #### periodic_100_6561

# %%
parameters["grid_folder"]="/home/linneu/ssh_grids/ssh1/periodic_100_6561"
parameters["csv_name"]="/home/linneu/ssh_csvs/ssh1/periodic_100_6561.csv"
output_file = "preprocessing_output_ssh1_periodic_100_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T03:40:18.396562',
#      'end_time': '2020-03-05T03:40:18.437704',
#      'duration': 0.041142,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T03:40:18.455247',
#      'end_time': '2020-03-05T03:40:18.467246',
#      'duration': 0.011999,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T03:40:18.479609',
#      'end_time': '2020-03-05T03:40:18.862328',
# ...

# %% [markdown]
# #### periodic_140_6561

# %%
parameters["grid_folder"]="/home/linneu/ssh_grids/ssh1/periodic_140_6561"
parameters["csv_name"]="/home/linneu/ssh_csvs/ssh1/periodic_140_6561.csv"
output_file = "preprocessing_output_ssh1_periodic_140_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T03:42:02.886650',
#      'end_time': '2020-03-05T03:42:02.903291',
#      'duration': 0.016641,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T03:42:02.913874',
#      'end_time': '2020-03-05T03:42:02.922882',
#      'duration': 0.009008,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T03:42:02.933266',
#      'end_time': '2020-03-05T03:42:03.220194',
# ...

# %% [markdown]
# #### periodic_180_6561

# %%
parameters["grid_folder"]="/home/linneu/ssh_grids/ssh1/periodic_180_6561"
parameters["csv_name"]="/home/linneu/ssh_csvs/ssh1/periodic_180_6561.csv"
output_file = "preprocessing_output_ssh1_periodic_180_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T03:45:58.948928',
#      'end_time': '2020-03-05T03:45:58.967691',
#      'duration': 0.018763,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T03:45:58.981150',
#      'end_time': '2020-03-05T03:45:58.992972',
#      'duration': 0.011822,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T03:45:59.004604',
#      'end_time': '2020-03-05T03:45:59.293694',
# ...

# %% [markdown]
# #### periodic_220_6561

# %%
parameters["grid_folder"]="/home/linneu/ssh_grids/ssh1/periodic_220_6561"
parameters["csv_name"]="/home/linneu/ssh_csvs/ssh1/periodic_220_6561.csv"
output_file = "preprocessing_output_ssh1_periodic_220_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T03:52:15.753495',
#      'end_time': '2020-03-05T03:52:15.772150',
#      'duration': 0.018655,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T03:52:15.785871',
#      'end_time': '2020-03-05T03:52:15.797517',
#      'duration': 0.011646,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T03:52:15.808982',
#      'end_time': '2020-03-05T03:52:16.159703',
# ...

# %% [markdown]
# ## SSH 2

# %%
template = "preprocessing_template.ipynb"
parameters = {"allowed_windings":[-1,0,1,2], "epsilon":0.01, "to_csv":True}
kernel_name = "ml_top_phases"

# %% [markdown]
# #### periodic_100_6561

# %%
parameters["grid_folder"]="/home/linneu/ssh_grids/ssh2/periodic_100_6561"
parameters["csv_name"]="/home/linneu/ssh_csvs/ssh2/periodic_100_6561.csv"
output_file = "preprocessing_output_ssh2_periodic_100_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T04:00:52.668833',
#      'end_time': '2020-03-05T04:00:52.686352',
#      'duration': 0.017519,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T04:00:52.700004',
#      'end_time': '2020-03-05T04:00:52.712407',
#      'duration': 0.012403,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T04:00:52.724069',
#      'end_time': '2020-03-05T04:00:53.047038',
# ...

# %% [markdown]
# #### periodic_140_6561

# %%
parameters["grid_folder"]="/home/linneu/ssh_grids/ssh2/periodic_140_6561"
parameters["csv_name"]="/home/linneu/ssh_csvs/ssh2/periodic_140_6561.csv"
output_file = "preprocessing_output_ssh2_periodic_140_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T04:03:17.404603',
#      'end_time': '2020-03-05T04:03:17.423874',
#      'duration': 0.019271,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T04:03:17.437630',
#      'end_time': '2020-03-05T04:03:17.449580',
#      'duration': 0.01195,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T04:03:17.461740',
#      'end_time': '2020-03-05T04:03:17.755122',
# ...

# %% [markdown]
# #### periodic_180_6561

# %%
parameters["grid_folder"]="/home/linneu/ssh_grids/ssh2/periodic_180_6561"
parameters["csv_name"]="/home/linneu/ssh_csvs/ssh2/periodic_180_6561.csv"
output_file = "preprocessing_output_ssh2_periodic_180_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T04:07:32.867683',
#      'end_time': '2020-03-05T04:07:32.887550',
#      'duration': 0.019867,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T04:07:32.901194',
#      'end_time': '2020-03-05T04:07:32.913509',
#      'duration': 0.012315,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-05T04:07:32.925204',
#      'end_time': '2020-03-05T04:07:33.214861',
# ...

# %% [markdown]
# #### periodic_220_6561

# %%
parameters["grid_folder"]="/home/linneu/ssh_grids/ssh2/periodic_220_6561"
parameters["csv_name"]="/home/linneu/ssh_csvs/ssh2/periodic_220_6561.csv"
output_file = "preprocessing_output_ssh2_periodic_220_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
