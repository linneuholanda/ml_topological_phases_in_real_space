# %% [markdown]
# # Running simulation template
#
# This notebook runs the template notebook `simulation_template.ipynb`, which performs simulations for nearest neighbours (ssh1) and second neighbours (ssh2) systems.

# %%
import papermill as pm

# %% [markdown]
# ## SSH1

# %%
template = "simulation_template.ipynb"
parameters = {"model_kw":{"criterion":"entropy"}, \
             "allowed_windings":[0,1], "val_split":0.9, "features_to_use":None, "shuffle_features":False,\
             "n_experiments":100, "start_n":0, "fit_params":None, "shuffle_rows": True,"pred_params":None,\
             "random_features":False, "store_in_lists":False, "save_eigenvector":True,\
             "save_hamiltonian":True, "save_accuracy":True, "save_models":True,\
             }
kernel_name = "ml_top_phases"

# %% [markdown]
# #### periodic_100_6561

# %%
# %%time
parameters["csv_path"] = "/home/linneu/ssh_csvs/ssh1/periodic_100_6561.csv"
parameters["model_name"] = "DecisionTreeClassifier"
parameters["simulation_dir"] = "/home/linneu/ssh_simulations/ssh1/periodic_100_6561"
parameters["random_state"] = 133
output_file = "simulation_output_ssh1_periodic_100_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-06T03:29:27.424249',
#      'end_time': '2020-03-06T03:29:27.449070',
#      'duration': 0.024821,
#      'status': 'completed'}},
#    'source': '# Simulation template.\n\nIn this notebook we produce the results of the machine learning analysis of topological phase transitions occurring  in both nearest-neighbours SSH models (ssh1) and second neighbours models (ssh2) as decribed in the paper [Machine learning topological phases in real space](https://arxiv.org/abs/1901.01963).'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-06T03:29:27.464268',
#      'end_time': '2020-03-06T03:29:27.478064',
#      'duration': 0.013796,
#      'status': 'completed'}},
#    'source': '## Defining parameters'},
#   {'cell_type': 'code',
#    'execution_count': 1,
# ...

# %% [markdown]
# #### periodic_140_6561

# %%
# %%time
parameters["csv_path"] = "/home/linneu/ssh_csvs/ssh1/periodic_140_6561.csv"
parameters["model_name"] = "DecisionTreeClassifier"
parameters["simulation_dir"] = "/home/linneu/ssh_simulations/ssh1/periodic_140_6561"
parameters["random_state"] = 147
output_file = "simulation_output_ssh1_periodic_140_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-06T03:53:14.400270',
#      'end_time': '2020-03-06T03:53:14.420329',
#      'duration': 0.020059,
#      'status': 'completed'}},
#    'source': '# Simulation template.\n\nIn this notebook we produce the results of the machine learning analysis of topological phase transitions occurring  in both nearest-neighbours SSH models (ssh1) and second neighbours models (ssh2) as decribed in the paper [Machine learning topological phases in real space](https://arxiv.org/abs/1901.01963).'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-06T03:53:14.435606',
#      'end_time': '2020-03-06T03:53:14.449339',
#      'duration': 0.013733,
#      'status': 'completed'}},
#    'source': '## Defining parameters'},
#   {'cell_type': 'code',
#    'execution_count': 1,
# ...

# %% [markdown]
# #### periodic_180_6561

# %%
# %%time
parameters["csv_path"] = "/home/linneu/ssh_csvs/ssh1/periodic_180_6561.csv"
parameters["model_name"] = "DecisionTreeClassifier"
parameters["simulation_dir"] = "/home/linneu/ssh_simulations/ssh1/periodic_180_6561"
parameters["random_state"] = 222
output_file = "simulation_output_ssh1_periodic_180_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-06T04:37:38.925755',
#      'end_time': '2020-03-06T04:37:38.944479',
#      'duration': 0.018724,
#      'status': 'completed'}},
#    'source': '# Simulation template.\n\nIn this notebook we produce the results of the machine learning analysis of topological phase transitions occurring  in both nearest-neighbours SSH models (ssh1) and second neighbours models (ssh2) as decribed in the paper [Machine learning topological phases in real space](https://arxiv.org/abs/1901.01963).'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-06T04:37:38.955700',
#      'end_time': '2020-03-06T04:37:38.965577',
#      'duration': 0.009877,
#      'status': 'completed'}},
#    'source': '## Defining parameters'},
#   {'cell_type': 'code',
#    'execution_count': 1,
# ...

# %% [markdown]
# #### periodic_220_6561

# %%
# %%time
parameters["csv_path"] = "/home/linneu/ssh_csvs/ssh1/periodic_220_6561.csv"
parameters["model_name"] = "DecisionTreeClassifier"
parameters["simulation_dir"] = "/home/linneu/ssh_simulations/ssh1/periodic_220_6561"
parameters["random_state"] = 345
output_file = "simulation_output_ssh1_periodic_220_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-06T05:49:56.548814',
#      'end_time': '2020-03-06T05:49:56.568709',
#      'duration': 0.019895,
#      'status': 'completed'}},
#    'source': '# Simulation template.\n\nIn this notebook we produce the results of the machine learning analysis of topological phase transitions occurring  in both nearest-neighbours SSH models (ssh1) and second neighbours models (ssh2) as decribed in the paper [Machine learning topological phases in real space](https://arxiv.org/abs/1901.01963).'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-06T05:49:56.584021',
#      'end_time': '2020-03-06T05:49:56.597704',
#      'duration': 0.013683,
#      'status': 'completed'}},
#    'source': '## Defining parameters'},
#   {'cell_type': 'code',
#    'execution_count': 1,
# ...

# %% [markdown]
# ## SSH2

# %%
template = "simulation_template.ipynb"
parameters = {"model_kw":{"criterion":"entropy", "n_estimators":25, "n_jobs":-1}, \
             "allowed_windings":[-1,0,1,2], "val_split":0.5, "features_to_use":None, "shuffle_features":False,\
             "n_experiments":100, "start_n":0, "fit_params":None, "shuffle_rows": True,"pred_params":None,\
             "random_features":False, "store_in_lists":False, "save_eigenvector":True,\
             "save_hamiltonian":True, "save_accuracy":True, "save_models":True,\
             }
kernel_name = "ml_top_phases"

# %% [markdown]
# #### periodic_100_6561

# %%
# %%time
parameters["csv_path"] = "/home/linneu/ssh_csvs/ssh2/periodic_100_6561.csv"
parameters["model_name"] = "RandomForestClassifier"
parameters["simulation_dir"] = "/home/linneu/ssh_simulations/ssh2/periodic_100_6561"
parameters["random_state"] = 834
output_file = "simulation_output_ssh2_periodic_100_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-06T07:33:03.414050',
#      'end_time': '2020-03-06T07:33:03.430687',
#      'duration': 0.016637,
#      'status': 'completed'}},
#    'source': '# Simulation template.\n\nIn this notebook we produce the results of the machine learning analysis of topological phase transitions occurring  in both nearest-neighbours SSH models (ssh1) and second neighbours models (ssh2) as decribed in the paper [Machine learning topological phases in real space](https://arxiv.org/abs/1901.01963).'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-06T07:33:03.441770',
#      'end_time': '2020-03-06T07:33:03.452349',
#      'duration': 0.010579,
#      'status': 'completed'}},
#    'source': '## Defining parameters'},
#   {'cell_type': 'code',
#    'execution_count': 1,
# ...

# %% [markdown]
# #### periodic_140_6561

# %%
# %%time
parameters["csv_path"] = "/home/linneu/ssh_csvs/ssh2/periodic_140_6561.csv"
parameters["model_name"] = "RandomForestClassifier"
parameters["simulation_dir"] = "/home/linneu/ssh_simulations/ssh2/periodic_140_6561"
parameters["random_state"] = 729
output_file = "simulation_output_ssh2_periodic_140_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-06T08:22:47.644465',
#      'end_time': '2020-03-06T08:22:47.664894',
#      'duration': 0.020429,
#      'status': 'completed'}},
#    'source': '# Simulation template.\n\nIn this notebook we produce the results of the machine learning analysis of topological phase transitions occurring  in both nearest-neighbours SSH models (ssh1) and second neighbours models (ssh2) as decribed in the paper [Machine learning topological phases in real space](https://arxiv.org/abs/1901.01963).'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-06T08:22:47.680267',
#      'end_time': '2020-03-06T08:22:47.694022',
#      'duration': 0.013755,
#      'status': 'completed'}},
#    'source': '## Defining parameters'},
#   {'cell_type': 'code',
#    'execution_count': 1,
# ...

# %% [markdown]
# #### periodic_180_6561

# %%
# %%time
parameters["csv_path"] = "/home/linneu/ssh_csvs/ssh2/periodic_180_6561.csv"
parameters["model_name"] = "RandomForestClassifier"
parameters["simulation_dir"] = "/home/linneu/ssh_simulations/ssh2/periodic_180_6561"
parameters["random_state"] = 193
output_file = "simulation_output_ssh2_periodic_180_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-06T09:44:05.587635',
#      'end_time': '2020-03-06T09:44:05.609384',
#      'duration': 0.021749,
#      'status': 'completed'}},
#    'source': '# Simulation template.\n\nIn this notebook we produce the results of the machine learning analysis of topological phase transitions occurring  in both nearest-neighbours SSH models (ssh1) and second neighbours models (ssh2) as decribed in the paper [Machine learning topological phases in real space](https://arxiv.org/abs/1901.01963).'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-06T09:44:05.624721',
#      'end_time': '2020-03-06T09:44:05.638817',
#      'duration': 0.014096,
#      'status': 'completed'}},
#    'source': '## Defining parameters'},
#   {'cell_type': 'code',
#    'execution_count': 1,
# ...

# %% [markdown]
# #### periodic_220_6561

# %%
# %%time
parameters["csv_path"] = "/home/linneu/ssh_csvs/ssh2/periodic_220_6561.csv"
parameters["model_name"] = "RandomForestClassifier"
parameters["simulation_dir"] = "/home/linneu/ssh_simulations/ssh2/periodic_220_6561"
parameters["random_state"] = 657
output_file = "simulation_output_ssh2_periodic_220_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-06T11:49:44.779871',
#      'end_time': '2020-03-06T11:49:44.797904',
#      'duration': 0.018033,
#      'status': 'completed'}},
#    'source': '# Simulation template.\n\nIn this notebook we produce the results of the machine learning analysis of topological phase transitions occurring  in both nearest-neighbours SSH models (ssh1) and second neighbours models (ssh2) as decribed in the paper [Machine learning topological phases in real space](https://arxiv.org/abs/1901.01963).'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-06T11:49:44.809149',
#      'end_time': '2020-03-06T11:49:44.819158',
#      'duration': 0.010009,
#      'status': 'completed'}},
#    'source': '## Defining parameters'},
#   {'cell_type': 'code',
#    'execution_count': 1,
# ...
