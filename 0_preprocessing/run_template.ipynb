# %% [markdown]
# # Running template
# This notebook runs the template notebook `preprocessing_template.ipynb` for both ssh1 and ssh2 grids.

# %%
import papermill as pm

# %% [markdown]
# ## SSH 1

# %%
template = "preprocessing_template.ipynb"
parameters = {"allowed_windings":[0,1], "epsilon":0.01, "csv_dir":"/home/rio/ssh_csvs/ssh1"}
#kernel_name = "ml_top_phases"
kernel_name = "ml_top_phases"

# %% [markdown]
# #### periodic_100_6561

# %%
parameters["grid_folder"]="/home/rio/ssh_grids/ssh1/periodic_100_6561"
parameters["csv_name"]="periodic_100_6561.csv"
output_file = "preprocessing_output_ssh1_periodic_100_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name,nest_asyncio=True)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-05T19:39:07.763031',
#      'end_time': '2020-04-05T19:39:07.773467',
#      'duration': 0.010436,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-05T19:39:07.780220',
#      'end_time': '2020-04-05T19:39:07.786177',
#      'duration': 0.005957,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-05T19:39:07.792306',
#      'end_time': '2020-04-05T19:39:08.008798',
# ...

# %% [markdown]
# #### periodic_140_6561

# %%
parameters["grid_folder"]="/home/rio/ssh_grids/ssh1/periodic_140_6561"
parameters["csv_name"]="periodic_140_6561.csv"
output_file = "preprocessing_output_ssh1_periodic_140_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-05T19:40:58.491768',
#      'end_time': '2020-04-05T19:40:58.552880',
#      'duration': 0.061112,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-05T19:40:58.561008',
#      'end_time': '2020-04-05T19:40:58.568171',
#      'duration': 0.007163,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-05T19:40:58.576615',
#      'end_time': '2020-04-05T19:40:58.801525',
# ...

# %% [markdown]
# #### periodic_180_6561

# %%
parameters["grid_folder"]="/home/rio/ssh_grids/ssh1/periodic_180_6561"
parameters["csv_name"]="periodic_180_6561.csv"
output_file = "preprocessing_output_ssh1_periodic_180_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-05T19:44:33.849893',
#      'end_time': '2020-04-05T19:44:33.883767',
#      'duration': 0.033874,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-05T19:44:33.902718',
#      'end_time': '2020-04-05T19:44:33.912649',
#      'duration': 0.009931,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-05T19:44:33.920711',
#      'end_time': '2020-04-05T19:44:34.134915',
# ...

# %% [markdown]
# #### periodic_220_6561

# %%
parameters["grid_folder"]="/home/rio/ssh_grids/ssh1/periodic_220_6561"
parameters["csv_name"]="periodic_220_6561.csv"
output_file = "preprocessing_output_ssh1_periodic_220_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-05T19:49:53.159070',
#      'end_time': '2020-04-05T19:49:53.169767',
#      'duration': 0.010697,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-05T19:49:53.176813',
#      'end_time': '2020-04-05T19:49:53.182857',
#      'duration': 0.006044,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-05T19:49:53.191047',
#      'end_time': '2020-04-05T19:49:53.430634',
# ...

# %% [markdown]
# ## SSH 2

# %%
template = "preprocessing_template.ipynb"
parameters = {"allowed_windings":[-1,0,1,2], "epsilon":0.01, "csv_dir":"/home/rio/ssh_csvs/ssh2"}
#kernel_name = "ml_top_phases"
kernel_name = "ml_top_phases"

# %% [markdown]
# #### periodic_100_6561

# %%
parameters["grid_folder"]="/home/rio/ssh_grids/ssh2/periodic_100_6561"
parameters["csv_name"]="periodic_100_6561.csv"
output_file = "preprocessing_output_ssh2_periodic_100_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-06T15:21:26.043629',
#      'end_time': '2020-04-06T15:21:26.052770',
#      'duration': 0.009141,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-06T15:21:26.064197',
#      'end_time': '2020-04-06T15:21:26.073004',
#      'duration': 0.008807,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-06T15:21:26.081934',
#      'end_time': '2020-04-06T15:21:26.766863',
# ...

# %% [markdown]
# #### periodic_140_6561

# %%
parameters["grid_folder"]="/home/rio/ssh_grids/ssh2/periodic_140_6561"
parameters["csv_name"]="periodic_140_6561.csv"
output_file = "preprocessing_output_ssh2_periodic_140_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-06T15:24:45.545426',
#      'end_time': '2020-04-06T15:24:45.579451',
#      'duration': 0.034025,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-06T15:24:45.596715',
#      'end_time': '2020-04-06T15:24:45.606679',
#      'duration': 0.009964,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-06T15:24:45.614390',
#      'end_time': '2020-04-06T15:24:45.829451',
# ...

# %% [markdown]
# #### periodic_180_6561

# %%
parameters["grid_folder"]="/home/rio/ssh_grids/ssh2/periodic_180_6561"
parameters["csv_name"]="periodic_180_6561.csv"
output_file = "preprocessing_output_ssh2_periodic_180_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-06T15:28:23.423111',
#      'end_time': '2020-04-06T15:28:23.434376',
#      'duration': 0.011265,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-06T15:28:23.441527',
#      'end_time': '2020-04-06T15:28:23.447545',
#      'duration': 0.006018,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-06T15:28:23.453886',
#      'end_time': '2020-04-06T15:28:23.675410',
# ...

# %% [markdown]
# #### periodic_220_6561

# %%
parameters["grid_folder"]="/home/rio/ssh_grids/ssh2/periodic_220_6561"
parameters["csv_name"]="periodic_220_6561.csv"
output_file = "preprocessing_output_ssh2_periodic_220_6561.ipynb"
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-06T15:33:48.948643',
#      'end_time': '2020-04-06T15:33:48.958475',
#      'duration': 0.009832,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-06T15:33:48.965317',
#      'end_time': '2020-04-06T15:33:48.971243',
#      'duration': 0.005926,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-04-06T15:33:48.979624',
#      'end_time': '2020-04-06T15:33:49.193044',
# ...
