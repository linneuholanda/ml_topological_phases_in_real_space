# %% [markdown]
# # Running template
# This notebook runs the template notebook `preprocessing_template.ipynb` for both ssh1 and ssh2 grids.

# %%
# %load_ext autoreload
# %autoreload 2
from preprocessing import *

# %% [markdown]
# ## SSH 1

# %%
template = TEMPLATE_NOTEBOOK
parameters = {"allowed_windings":[0,1], "epsilon":0.01, "csv_dir":SSH1_CSVS_DIR}
kernel_name = "ml_top_phases"

# %% [markdown]
# #### periodic_100_6561

# %%
parameters["grid_folder"]= SSH1_PERIODIC_100_6561_GRID_DIR
parameters["csv_name"]= SSH1_PERIODIC_100_6561_CSV
output_file = SSH1_PERIODIC_100_6561_OUTPUT_FILE 
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name,nest_asyncio=True)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T02:40:34.730876',
#      'end_time': '2020-05-01T02:40:34.766050',
#      'duration': 0.035174,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T02:40:34.782695',
#      'end_time': '2020-05-01T02:40:34.792251',
#      'duration': 0.009556,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T02:40:34.800112',
#      'end_time': '2020-05-01T02:40:35.093054',
# ...

# %% [markdown]
# #### periodic_140_6561

# %%
parameters["grid_folder"]= SSH1_PERIODIC_140_6561_GRID_DIR
parameters["csv_name"]= SSH1_PERIODIC_140_6561_CSV
output_file = SSH1_PERIODIC_140_6561_OUTPUT_FILE 
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name,nest_asyncio=True)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T02:42:54.089106',
#      'end_time': '2020-05-01T02:42:54.099292',
#      'duration': 0.010186,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T02:42:54.106058',
#      'end_time': '2020-05-01T02:42:54.111937',
#      'duration': 0.005879,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T02:42:54.119254',
#      'end_time': '2020-05-01T02:42:54.412335',
# ...

# %% [markdown]
# #### periodic_180_6561

# %%
parameters["grid_folder"]= SSH1_PERIODIC_180_6561_GRID_DIR
parameters["csv_name"]= SSH1_PERIODIC_180_6561_CSV
output_file = SSH1_PERIODIC_180_6561_OUTPUT_FILE 
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name,nest_asyncio=True)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T02:46:36.215352',
#      'end_time': '2020-05-01T02:46:36.248314',
#      'duration': 0.032962,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T02:46:36.265021',
#      'end_time': '2020-05-01T02:46:36.274811',
#      'duration': 0.00979,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T02:46:36.282896',
#      'end_time': '2020-05-01T02:46:36.576234',
# ...

# %% [markdown]
# #### periodic_220_6561

# %%
parameters["grid_folder"]= SSH1_PERIODIC_220_6561_GRID_DIR
parameters["csv_name"]= SSH1_PERIODIC_220_6561_CSV
output_file = SSH1_PERIODIC_220_6561_OUTPUT_FILE 
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name,nest_asyncio=True)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T02:51:57.709807',
#      'end_time': '2020-05-01T02:51:57.765816',
#      'duration': 0.056009,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T02:51:57.799324',
#      'end_time': '2020-05-01T02:51:57.815003',
#      'duration': 0.015679,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T02:51:57.830168',
#      'end_time': '2020-05-01T02:51:58.226834',
# ...

# %% [markdown]
# ## SSH 2

# %%
template = TEMPLATE_NOTEBOOK
parameters = {"allowed_windings":[-1,0,1,2], "epsilon":0.01, "csv_dir":SSH2_CSVS_DIR}
kernel_name = "ml_top_phases"

# %% [markdown]
# #### periodic_100_6561

# %%
parameters["grid_folder"]= SSH2_PERIODIC_100_6561_GRID_DIR
parameters["csv_name"]= SSH2_PERIODIC_100_6561_CSV
output_file = SSH2_PERIODIC_100_6561_OUTPUT_FILE 
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name,nest_asyncio=True)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T02:59:21.828610',
#      'end_time': '2020-05-01T02:59:21.862698',
#      'duration': 0.034088,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T02:59:21.879820',
#      'end_time': '2020-05-01T02:59:21.889221',
#      'duration': 0.009401,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T02:59:21.897184',
#      'end_time': '2020-05-01T02:59:24.183121',
# ...

# %% [markdown]
# #### periodic_140_6561

# %%
parameters["grid_folder"]= SSH2_PERIODIC_140_6561_GRID_DIR
parameters["csv_name"]= SSH2_PERIODIC_140_6561_CSV
output_file = SSH2_PERIODIC_140_6561_OUTPUT_FILE 
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name,nest_asyncio=True)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T03:01:50.767842',
#      'end_time': '2020-05-01T03:01:50.802374',
#      'duration': 0.034532,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T03:01:50.820342',
#      'end_time': '2020-05-01T03:01:50.829762',
#      'duration': 0.00942,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T03:01:50.837801',
#      'end_time': '2020-05-01T03:01:51.137592',
# ...

# %% [markdown]
# #### periodic_180_6561

# %%
parameters["grid_folder"]= SSH2_PERIODIC_180_6561_GRID_DIR
parameters["csv_name"]= SSH2_PERIODIC_180_6561_CSV
output_file = SSH2_PERIODIC_180_6561_OUTPUT_FILE 
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name,nest_asyncio=True)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T03:05:33.297688',
#      'end_time': '2020-05-01T03:05:33.308288',
#      'duration': 0.0106,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T03:05:33.315033',
#      'end_time': '2020-05-01T03:05:33.320910',
#      'duration': 0.005877,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T03:05:33.327122',
#      'end_time': '2020-05-01T03:05:33.628148',
# ...

# %% [markdown]
# #### periodic_220_6561

# %%
parameters["grid_folder"]= SSH2_PERIODIC_220_6561_GRID_DIR
parameters["csv_name"]= SSH2_PERIODIC_220_6561_CSV
output_file = SSH2_PERIODIC_220_6561_OUTPUT_FILE 
pm.execute_notebook(template,
                    output_file,
                    parameters=parameters,
                    kernel_name=kernel_name,nest_asyncio=True)
# Out:
# ...
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T03:10:58.692332',
#      'end_time': '2020-05-01T03:10:58.702493',
#      'duration': 0.010161,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T03:10:58.709349',
#      'end_time': '2020-05-01T03:10:58.715097',
#      'duration': 0.005748,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-05-01T03:10:58.721304',
#      'end_time': '2020-05-01T03:10:59.016606',
# ...
