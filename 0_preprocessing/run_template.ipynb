# %% [markdown]
# # Running papermill on templates

# %%
import papermill as pm
from tqdm import tqdm

# %% [markdown]
# ## SSH 1

# %%
#%%javascript
#var kernel = Jupyter.notebook.kernel
#kernel.execute('kernel_name = ' + '"' + kernel.name + '"')

# %%
template = "preprocessing_template.ipynb"
output = "preprocessing_output.ipynb"
parameters = {"allowed_windings":[0,1], "epsilon":0.01, "to_csv":True}
kernel_name = "ml_top_phases"
grid_folders_and_csv_names = [("/home/linneu/ssh_grids/ssh1/periodic_100_6561", "/home/linneu/ssh_csvs/ssh1/periodic_100_6561.csv"),\
                             ("/home/linneu/ssh_grids/ssh1/periodic_140_6561", "/home/linneu/ssh_csvs/ssh1/periodic_140_6561.csv"),\
                             ("/home/linneu/ssh_grids/ssh1/periodic_180_6561", "/home/linneu/ssh_csvs/ssh1/periodic_180_6561.csv"),\
                             ("/home/linneu/ssh_grids/ssh1/periodic_220_6561", "/home/linneu/ssh_csvs/ssh1/periodic_220_6561.csv")\
                             ]

# %%
nbs = []
for grid_folder, csv_name in tqdm(grid_folders_and_csv_names):
    parameters["grid_folder"]=grid_folder
    parameters["csv_name"]=csv_name
    nb = pm.execute_notebook(template,
                        output,
                        parameters=parameters,
                        kernel_name=kernel_name)
    nbs.append(nb)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# HBox(children=(FloatProgress(value=0.0, description='Executing', max=18.0, style=ProgressStyle(description_wid…
#  25%|██▌       | 1/4 [01:43<05:10, 103.64s/it]
# HBox(children=(FloatProgress(value=0.0, description='Executing', max=18.0, style=ProgressStyle(description_wid…
# Kernel died while waiting for execute reply.
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# ~/anaconda3/envs/ml_top_phases/lib/python3.6/site-packages/nbclient/client.py in _poll_for_reply(self, msg_id, cell, timeout)
#     413             # check with timeout if kernel is still alive
# --> 414             msg = self.kc.shell_channel.get_msg(timeout=timeout)
#     415             if msg['parent_header'].get('msg_id') == msg_id:
#
# ~/anaconda3/envs/ml_top_phases/lib/python3.6/site-packages/jupyter_client/blocking/channels.py in get_msg(self, block, timeout)
#      56         else:
# ---> 57             raise Empty
#      58
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# DeadKernelError                           Traceback (most recent call last)
# <ipython-input-4-e4b4f0bd5d44> in <module>
#       6                         output,
#       7                         parameters=parameters,
# ----> 8                         kernel_name=kernel_name)
#       9     nbs.append(nb)
#
# ~/anaconda3/envs/ml_top_phases/lib/python3.6/site-packages/papermill/execute.py in execute_notebook(input_path, output_path, parameters, engine_name, request_save_on_cell_execute, prepare_only, kernel_name, progress_bar, log_output, stdout_file, stderr_file, start_timeout, report_mode, cwd, **engine_kwargs)
#     102                     stdout_file=stdout_file,
#     103                     stderr_file=stderr_file,
# --> 104                     **engine_kwargs
#     105                 )
#     106
#
# ~/anaconda3/envs/ml_top_phases/lib/python3.6/site-packages/papermill/engines.py in execute_notebook_with_engine(self, engine_name, nb, kernel_name, **kwargs)
#      47     def execute_notebook_with_engine(self, engine_name, nb, kernel_name, **kwargs):
#      48         """Fetch a named engine and execute the nb object against it."""
# ---> 49         return self.get_engine(engine_name).execute_notebook(nb, kernel_name, **kwargs)
#      50
#      51
#
# ~/anaconda3/envs/ml_top_phases/lib/python3.6/site-packages/papermill/engines.py in execute_notebook(cls, nb, kernel_name, output_path, progress_bar, log_output, autosave_cell_every, **kwargs)
#     341         nb_man.notebook_start()
#     342         try:
# --> 343             cls.execute_managed_notebook(nb_man, kernel_name, log_output=log_output, **kwargs)
#     344         finally:
#     345             nb_man.cleanup_pbar()
#
# ~/anaconda3/envs/ml_top_phases/lib/python3.6/site-packages/papermill/engines.py in execute_managed_notebook(cls, nb_man, kernel_name, log_output, stdout_file, stderr_file, start_timeout, execution_timeout, **kwargs)
#     400             stderr_file=stderr_file,
#     401         )
# --> 402         return PapermillNotebookClient(nb_man, **final_kwargs).execute()
#     403
#     404
#
# ~/anaconda3/envs/ml_top_phases/lib/python3.6/site-packages/papermill/clientwrap.py in execute(self, **kwargs)
#      36         with self.setup_kernel(**kwargs):
#      37             self.log.info("Executing notebook with kernel: %s" % self.kernel_name)
# ---> 38             self.papermill_execute_cells()
#      39             info_msg = self._wait_for_reply(self.kc.kernel_info())
#      40             self.nb.metadata['language_info'] = info_msg['content']['language_info']
#
# ~/anaconda3/envs/ml_top_phases/lib/python3.6/site-packages/papermill/clientwrap.py in papermill_execute_cells(self)
#      63             try:
#      64                 self.nb_man.cell_start(cell, index)
# ---> 65                 self.execute_cell(cell, index)
#      66             except CellExecutionError as ex:
#      67                 self.nb_man.cell_exception(self.nb.cells[index], cell_index=index, exception=ex)
#
# ~/anaconda3/envs/ml_top_phases/lib/python3.6/site-packages/nbclient/client.py in execute_cell(self, cell, cell_index, execution_count, store_history)
#     561                 # after at most 1s so we can poll output from iopub_channel.
#     562                 timeout = self._timeout_with_deadline(1, deadline)
# --> 563                 exec_reply = self._poll_for_reply(parent_msg_id, cell, timeout)
#     564                 if exec_reply is not None:
#     565                     polling_exec_reply = False
#
# ~/anaconda3/envs/ml_top_phases/lib/python3.6/site-packages/nbclient/client.py in _poll_for_reply(self, msg_id, cell, timeout)
#     417         except Empty:
#     418             # received no message, check if kernel is still alive
# --> 419             self._check_alive()
#     420             # kernel still alive, wait for a message
#     421
#
# ~/anaconda3/envs/ml_top_phases/lib/python3.6/site-packages/nbclient/client.py in _check_alive(self)
#     444         if not self.kc.is_alive():
#     445             self.log.error("Kernel died while waiting for execute reply.")
# --> 446             raise DeadKernelError("Kernel died")
#     447
#     448     def _wait_for_reply(self, msg_id, cell=None):
#
# DeadKernelError: Kernel died

# %%
nbs[0]
# Out:
# {'cells': [{'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:31:00.535192',
#      'end_time': '2020-03-03T02:31:00.553478',
#      'duration': 0.018286,
#      'status': 'completed'}},
#    'source': '# Generate csv files \n'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:31:00.566348',
#      'end_time': '2020-03-03T02:31:00.577267',
#      'duration': 0.010919,
#      'status': 'completed'}},
#    'source': 'This notebook generates .csv files from a directory containing .dat files with Hamiltonian data. Each .dat file is assumed to be named as `"H_t1_t2_winding.dat"`.  '},
#   {'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:31:00.590376',
#      'end_time': '2020-03-03T02:31:00.958257',
#      'duration': 0.367881,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '#from IPython.core.display import HTML\n#HTML("<script>Jupyter.notebook.kernel.restart()</script>")\n%load_ext autoreload\n%autoreload 2\n\nfrom preprocessing import *'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:31:00.971758',
#      'end_time': '2020-03-03T02:31:00.982021',
#      'duration': 0.010263,
#      'status': 'completed'}},
#    'source': '### Set the parameters below carefully'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:31:00.995104',
#      'end_time': '2020-03-03T02:31:01.025110',
#      'duration': 0.030006,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'CPU times: user 4 µs, sys: 1 µs, total: 5 µs\nWall time: 7.87 µs\n'}],
#    'source': '%%time\ngrid_folder = "/home/linneu/ssh_grids/ssh1/periodic_100_6561"\nallowed_windings = [0,1]\nepsilon = 0.01\ncsv_name = "/home/linneu/ssh_csvs/ssh1/periodic_100_6561.csv"\nto_csv = True\n'},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:31:01.036802',
#      'end_time': '2020-03-03T02:31:01.065761',
#      'duration': 0.028959,
#      'status': 'completed'}},
#    'execution_count': 3,
#    'source': '# Parameters\nallowed_windings = [0, 1]\nepsilon = 0.01\nto_csv = True\ngrid_folder = "/home/linneu/ssh_grids/ssh1/periodic_100_6561"\ncsv_name = "/home/linneu/ssh_csvs/ssh1/periodic_100_6561.csv"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:31:01.081764',
#      'end_time': '2020-03-03T02:32:35.923980',
#      'duration': 94.842216,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:   0%|          | 0/6561 [00:00<?, ?it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:   1%|▏         | 85/6561 [00:00<00:07, 841.96it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:   3%|▎         | 168/6561 [00:00<00:07, 836.60it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:   4%|▍         | 247/6561 [00:00<00:07, 821.93it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:   5%|▌         | 329/6561 [00:00<00:07, 818.20it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:   6%|▌         | 408/6561 [00:00<00:07, 808.22it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:   7%|▋         | 488/6561 [00:00<00:07, 804.93it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:   9%|▊         | 567/6561 [00:00<00:07, 799.22it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  10%|▉         | 651/6561 [00:00<00:07, 797.08it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  11%|█         | 736/6561 [00:00<00:07, 783.41it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  12%|█▏        | 819/6561 [00:01<00:07, 782.06it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  14%|█▎        | 895/6561 [00:01<00:11, 492.79it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  15%|█▍        | 973/6561 [00:01<00:10, 553.44it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  16%|█▌        | 1052/6561 [00:01<00:09, 607.34it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  17%|█▋        | 1133/6561 [00:01<00:08, 655.80it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  18%|█▊        | 1212/6561 [00:01<00:07, 690.41it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  20%|█▉        | 1291/6561 [00:01<00:07, 717.37it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  21%|██        | 1369/6561 [00:01<00:07, 733.54it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  22%|██▏       | 1446/6561 [00:02<00:06, 743.34it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  23%|██▎       | 1524/6561 [00:02<00:06, 753.57it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  24%|██▍       | 1603/6561 [00:02<00:06, 760.04it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  26%|██▌       | 1682/6561 [00:02<00:06, 768.37it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  27%|██▋       | 1760/6561 [00:02<00:13, 345.96it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  28%|██▊       | 1841/6561 [00:02<00:11, 414.97it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  29%|██▉       | 1925/6561 [00:03<00:09, 483.68it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  31%|███       | 2009/6561 [00:03<00:08, 551.01it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  32%|███▏      | 2093/6561 [00:03<00:07, 609.46it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  33%|███▎      | 2177/6561 [00:03<00:06, 658.08it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  34%|███▍      | 2261/6561 [00:03<00:06, 696.23it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  36%|███▌      | 2345/6561 [00:03<00:05, 725.30it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  37%|███▋      | 2429/6561 [00:03<00:05, 747.18it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  38%|███▊      | 2513/6561 [00:03<00:05, 764.02it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  40%|███▉      | 2597/6561 [00:03<00:05, 778.01it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  41%|████      | 2681/6561 [00:03<00:04, 788.50it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  42%|████▏     | 2762/6561 [00:04<00:13, 287.97it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  43%|████▎     | 2842/6561 [00:04<00:10, 355.57it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  45%|████▍     | 2924/6561 [00:04<00:08, 427.82it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  46%|████▌     | 3005/6561 [00:04<00:07, 498.27it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  47%|████▋     | 3087/6561 [00:05<00:06, 563.66it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  48%|████▊     | 3171/6561 [00:05<00:05, 624.02it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  50%|████▉     | 3253/6561 [00:05<00:04, 671.18it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  51%|█████     | 3335/6561 [00:05<00:04, 708.37it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  52%|█████▏    | 3416/6561 [00:05<00:04, 733.27it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  53%|█████▎    | 3496/6561 [00:05<00:04, 745.24it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  55%|█████▍    | 3576/6561 [00:05<00:03, 756.09it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  56%|█████▌    | 3655/6561 [00:06<00:12, 228.20it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  57%|█████▋    | 3738/6561 [00:06<00:09, 291.44it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  58%|█████▊    | 3821/6561 [00:06<00:07, 361.78it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  59%|█████▉    | 3902/6561 [00:06<00:06, 433.56it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  61%|██████    | 3983/6561 [00:07<00:05, 503.19it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  62%|██████▏   | 4063/6561 [00:07<00:04, 566.13it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  63%|██████▎   | 4144/6561 [00:07<00:03, 621.93it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  64%|██████▍   | 4225/6561 [00:07<00:03, 667.84it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  66%|██████▌   | 4305/6561 [00:07<00:03, 701.24it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  67%|██████▋   | 4385/6561 [00:07<00:02, 726.63it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  68%|██████▊   | 4466/6561 [00:07<00:02, 746.37it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  69%|██████▉   | 4548/6561 [00:07<00:02, 764.83it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  71%|███████   | 4628/6561 [00:07<00:02, 772.83it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  72%|███████▏  | 4711/6561 [00:07<00:02, 781.32it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  73%|███████▎  | 4795/6561 [00:08<00:02, 788.58it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  74%|███████▍  | 4876/6561 [00:09<00:08, 193.41it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  76%|███████▌  | 4959/6561 [00:09<00:06, 251.08it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  77%|███████▋  | 5041/6561 [00:09<00:04, 316.91it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  78%|███████▊  | 5123/6561 [00:09<00:03, 388.07it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  79%|███████▉  | 5205/6561 [00:09<00:02, 460.31it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  81%|████████  | 5287/6561 [00:09<00:02, 529.43it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  82%|████████▏ | 5369/6561 [00:09<00:02, 590.17it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  83%|████████▎ | 5451/6561 [00:09<00:01, 644.30it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  84%|████████▍ | 5532/6561 [00:09<00:01, 686.01it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  86%|████████▌ | 5614/6561 [00:10<00:01, 717.92it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  87%|████████▋ | 5696/6561 [00:10<00:01, 744.11it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  88%|████████▊ | 5777/6561 [00:10<00:01, 762.01it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  89%|████████▉ | 5858/6561 [00:10<00:00, 771.85it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  91%|█████████ | 5939/6561 [00:10<00:00, 773.75it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  92%|█████████▏| 6019/6561 [00:10<00:00, 779.79it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  93%|█████████▎| 6099/6561 [00:10<00:00, 782.89it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  94%|█████████▍| 6179/6561 [00:10<00:00, 784.84it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  95%|█████████▌| 6259/6561 [00:12<00:01, 152.22it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  97%|█████████▋| 6338/6561 [00:12<00:01, 200.75it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  98%|█████████▊| 6417/6561 [00:12<00:00, 258.39it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians:  99%|█████████▉| 6489/6561 [00:12<00:00, 319.22it/s]'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '\rloading hamiltonians: 100%|██████████| 6561/6561 [00:12<00:00, 516.39it/s]'},
#     {'output_type': 'stream', 'name': 'stderr', 'text': '\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'shape of raw_data:  (656100, 104)\nlen list_of_hamiltonians:  6561\n'},
#     {'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'CPU times: user 1min 26s, sys: 7.9 s, total: 1min 34s\nWall time: 1min 34s\n'}],
#    'source': '%%time\nlist_of_hamiltonians, raw_data = load_hamiltonians(grid_folder)\nprint("shape of raw_data: ", raw_data.shape)\nprint("len list_of_hamiltonians: ", len(list_of_hamiltonians))\n\ndataframe = make_dataframe(raw_data, list_of_hamiltonians, allowed_windings = allowed_windings, epsilon = epsilon, \\\n                           csv_name = csv_name, to_csv = to_csv)'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:32:35.962210',
#      'end_time': '2020-03-03T02:32:36.075726',
#      'duration': 0.113516,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': "<class 'pandas.core.frame.DataFrame'>\nRangeIndex: 656100 entries, 0 to 656099\nColumns: 108 entries, id to feat99\ndtypes: float64(3), int32(1), int64(2), object(102)\nmemory usage: 538.1+ MB\n"},
#     {'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '   id                  path   t1   t2   winding  phase  pred_phase type_of  \\\n0   0  H_-2_-2_0.509296.dat -2.0 -2.0  0.509296    999         666    test   \n1   0  H_-2_-2_0.509296.dat -2.0 -2.0  0.509296    999         666    test   \n2   0  H_-2_-2_0.509296.dat -2.0 -2.0  0.509296    999         666    test   \n3   0  H_-2_-2_0.509296.dat -2.0 -2.0  0.509296    999         666    test   \n4   0  H_-2_-2_0.509296.dat -2.0 -2.0  0.509296    999         666    test   \n\n       feat0      feat1  ...     feat90     feat91     feat92     feat93  \\\n0   0.100000   0.100000  ...   0.100000   0.100000   0.100000   0.100000   \n1   0.141421   0.141142  ...   0.114412   0.108967   0.123928   0.119406   \n2   0.141421   0.140306  ...   0.043702   0.026500   0.075777   0.060214   \n3  -0.100000   0.100000  ...  -0.100000   0.100000  -0.100000   0.100000   \n4   0.000509  -0.008372  ...  -0.082713  -0.089753  -0.067684  -0.075347   \n\n      feat94     feat95     feat96     feat97     feat98     feat99  \n0   0.100000   0.100000   0.100000   0.100000   0.100000   0.100000  \n1   0.131490   0.127962   0.136978   0.134500   0.140306   0.138916  \n2   0.103092   0.090145   0.123928   0.114412   0.136978   0.131490  \n3  -0.100000   0.100000  -0.100000   0.100000  -0.100000   0.100000  \n4  -0.051587  -0.059753  -0.034677  -0.043217  -0.017220  -0.026000  \n\n[5 rows x 108 columns]',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>id</th>\n      <th>path</th>\n      <th>t1</th>\n      <th>t2</th>\n      <th>winding</th>\n      <th>phase</th>\n      <th>pred_phase</th>\n      <th>type_of</th>\n      <th>feat0</th>\n      <th>feat1</th>\n      <th>...</th>\n      <th>feat90</th>\n      <th>feat91</th>\n      <th>feat92</th>\n      <th>feat93</th>\n      <th>feat94</th>\n      <th>feat95</th>\n      <th>feat96</th>\n      <th>feat97</th>\n      <th>feat98</th>\n      <th>feat99</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>H_-2_-2_0.509296.dat</td>\n      <td>-2.0</td>\n      <td>-2.0</td>\n      <td>0.509296</td>\n      <td>999</td>\n      <td>666</td>\n      <td>test</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>...</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>0</td>\n      <td>H_-2_-2_0.509296.dat</td>\n      <td>-2.0</td>\n      <td>-2.0</td>\n      <td>0.509296</td>\n      <td>999</td>\n      <td>666</td>\n      <td>test</td>\n      <td>0.141421</td>\n      <td>0.141142</td>\n      <td>...</td>\n      <td>0.114412</td>\n      <td>0.108967</td>\n      <td>0.123928</td>\n      <td>0.119406</td>\n      <td>0.131490</td>\n      <td>0.127962</td>\n      <td>0.136978</td>\n      <td>0.134500</td>\n      <td>0.140306</td>\n      <td>0.138916</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>0</td>\n      <td>H_-2_-2_0.509296.dat</td>\n      <td>-2.0</td>\n      <td>-2.0</td>\n      <td>0.509296</td>\n      <td>999</td>\n      <td>666</td>\n      <td>test</td>\n      <td>0.141421</td>\n      <td>0.140306</td>\n      <td>...</td>\n      <td>0.043702</td>\n      <td>0.026500</td>\n      <td>0.075777</td>\n      <td>0.060214</td>\n      <td>0.103092</td>\n      <td>0.090145</td>\n      <td>0.123928</td>\n      <td>0.114412</td>\n      <td>0.136978</td>\n      <td>0.131490</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>0</td>\n      <td>H_-2_-2_0.509296.dat</td>\n      <td>-2.0</td>\n      <td>-2.0</td>\n      <td>0.509296</td>\n      <td>999</td>\n      <td>666</td>\n      <td>test</td>\n      <td>-0.100000</td>\n      <td>0.100000</td>\n      <td>...</td>\n      <td>-0.100000</td>\n      <td>0.100000</td>\n      <td>-0.100000</td>\n      <td>0.100000</td>\n      <td>-0.100000</td>\n      <td>0.100000</td>\n      <td>-0.100000</td>\n      <td>0.100000</td>\n      <td>-0.100000</td>\n      <td>0.100000</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>0</td>\n      <td>H_-2_-2_0.509296.dat</td>\n      <td>-2.0</td>\n      <td>-2.0</td>\n      <td>0.509296</td>\n      <td>999</td>\n      <td>666</td>\n      <td>test</td>\n      <td>0.000509</td>\n      <td>-0.008372</td>\n      <td>...</td>\n      <td>-0.082713</td>\n      <td>-0.089753</td>\n      <td>-0.067684</td>\n      <td>-0.075347</td>\n      <td>-0.051587</td>\n      <td>-0.059753</td>\n      <td>-0.034677</td>\n      <td>-0.043217</td>\n      <td>-0.017220</td>\n      <td>-0.026000</td>\n    </tr>\n  </tbody>\n</table>\n<p>5 rows × 108 columns</p>\n</div>'},
#      'execution_count': 5}],
#    'source': 'dataframe.info()\ndataframe.head()\n#dataframe.tail()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:32:36.120250',
#      'end_time': '2020-03-03T02:32:36.158237',
#      'duration': 0.037987,
#      'status': 'completed'}},
#    'source': '#### Checking t values are row-major sorted'},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:32:36.196488',
#      'end_time': '2020-03-03T02:32:36.263141',
#      'duration': 0.066653,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 't_array:\n [[-2. -2.]\n [-2. -2.]\n [-2. -2.]\n ...\n [ 2.  2.]\n [ 2.  2.]\n [ 2.  2.]]\n'}],
#    'source': '#np.set_printoptions(threshold=np.inf)\nt_array = dataframe[["t1", "t2"]].values\nprint("t_array:\\n", t_array)\nnp.set_printoptions()'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:32:36.306026',
#      'end_time': '2020-03-03T02:32:36.344454',
#      'duration': 0.038428,
#      'status': 'completed'}},
#    'source': '#### Making a grid'},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:32:36.382530',
#      'end_time': '2020-03-03T02:32:36.447046',
#      'duration': 0.064516,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': 'xx: \n [-2. -2. -2. ...  2.  2.  2.]\nyy: \n [-2. -2. -2. ...  2.  2.  2.]\n'}],
#    'source': 'xx = dataframe.t2.values\nyy = dataframe.t1.values\nprint("xx: \\n", xx)\nprint("yy: \\n", yy)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:32:36.490927',
#      'end_time': '2020-03-03T02:32:36.529710',
#      'duration': 0.038783,
#      'status': 'completed'}},
#    'source': '#### Train/test '},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:32:36.569037',
#      'end_time': '2020-03-03T02:32:40.344497',
#      'duration': 3.77546,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stdout',
#      'text': '% train:  0.846822130772748\n% test:  0.15317786922725193\n% train + test:  1.0\n'}],
#    'source': 'n_total = len(dataframe)\nn_train = len(dataframe[dataframe.type_of == "train"])\nn_test = len(dataframe[dataframe.type_of == "test"])\nprint("% train: ", n_train/n_total)\nprint("% test: ", n_test/n_total)\nprint("% train + test: ", (n_train+n_test)/n_total)'},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:32:40.389412',
#      'end_time': '2020-03-03T02:32:42.428326',
#      'duration': 2.038914,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '      id                        path   t1    t2   winding  phase  pred_phase  \\\n900    9  H_-2_-1.55_-0.00906169.dat -2.0 -1.55 -0.009062      0         666   \n901    9  H_-2_-1.55_-0.00906169.dat -2.0 -1.55 -0.009062      0         666   \n902    9  H_-2_-1.55_-0.00906169.dat -2.0 -1.55 -0.009062      0         666   \n903    9  H_-2_-1.55_-0.00906169.dat -2.0 -1.55 -0.009062      0         666   \n904    9  H_-2_-1.55_-0.00906169.dat -2.0 -1.55 -0.009062      0         666   \n...   ..                         ...  ...   ...       ...    ...         ...   \n1895  18   H_-2_-1.1_-0.00325923.dat -2.0 -1.10 -0.003259      0         666   \n1896  18   H_-2_-1.1_-0.00325923.dat -2.0 -1.10 -0.003259      0         666   \n1897  18   H_-2_-1.1_-0.00325923.dat -2.0 -1.10 -0.003259      0         666   \n1898  18   H_-2_-1.1_-0.00325923.dat -2.0 -1.10 -0.003259      0         666   \n1899  18   H_-2_-1.1_-0.00325923.dat -2.0 -1.10 -0.003259      0         666   \n\n     type_of      feat0      feat1  ...     feat90     feat91     feat92  \\\n900    train   0.100000   0.100000  ...   0.100000   0.100000   0.100000   \n901    train   0.100000  -0.100000  ...   0.100000  -0.100000   0.100000   \n902    train   0.141421   0.141209  ...   0.114412   0.109682   0.123928   \n903    train   0.141421   0.139516  ...  -0.043702  -0.065115   0.008880   \n904    train   0.141421   0.140572  ...   0.043702   0.028721   0.075777   \n...      ...        ...        ...  ...        ...        ...        ...   \n1895   train   0.141421   0.135641  ...  -0.043989  -0.079976   0.076032   \n1896   train  -0.000125   0.077667  ...  -0.134461  -0.136402   0.109047   \n1897   train  -0.001253   0.038525  ...   0.134882   0.117508  -0.120073   \n1898   train   0.000341   0.077486  ...   0.134394  -0.136459  -0.109184   \n1899   train   0.001695   0.038100  ...  -0.135014   0.117753   0.120306   \n\n         feat93     feat94     feat95     feat96     feat97     feat98  \\\n900    0.100000   0.100000   0.100000   0.100000   0.100000   0.100000   \n901   -0.100000   0.100000  -0.100000   0.100000  -0.100000   0.100000   \n902    0.120007   0.131490   0.128438   0.136978   0.134844   0.140306   \n903   -0.014328   0.060214   0.038471   0.103092   0.085867   0.131490   \n904    0.062255   0.103092   0.091879   0.123928   0.115729   0.136978   \n...         ...        ...        ...        ...        ...        ...   \n1895   0.106469  -0.103298  -0.126273   0.124074   0.138142  -0.137053   \n1896   0.041557   0.017601   0.091867  -0.127909  -0.140007   0.119473   \n1897  -0.094248   0.097719   0.065065  -0.069226  -0.031794   0.036383   \n1898   0.041764  -0.017387   0.091702   0.127816  -0.140037  -0.119588   \n1899  -0.094576  -0.098038   0.065457   0.069610  -0.032224  -0.036809   \n\n         feat99  \n900    0.100000  \n901   -0.100000  \n902    0.139123  \n903    0.121203  \n904    0.132307  \n...         ...  \n1895  -0.141332  \n1896   0.058172  \n1897  -0.003474  \n1898   0.058369  \n1899  -0.003033  \n\n[1000 rows x 108 columns]',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>id</th>\n      <th>path</th>\n      <th>t1</th>\n      <th>t2</th>\n      <th>winding</th>\n      <th>phase</th>\n      <th>pred_phase</th>\n      <th>type_of</th>\n      <th>feat0</th>\n      <th>feat1</th>\n      <th>...</th>\n      <th>feat90</th>\n      <th>feat91</th>\n      <th>feat92</th>\n      <th>feat93</th>\n      <th>feat94</th>\n      <th>feat95</th>\n      <th>feat96</th>\n      <th>feat97</th>\n      <th>feat98</th>\n      <th>feat99</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>900</th>\n      <td>9</td>\n      <td>H_-2_-1.55_-0.00906169.dat</td>\n      <td>-2.0</td>\n      <td>-1.55</td>\n      <td>-0.009062</td>\n      <td>0</td>\n      <td>666</td>\n      <td>train</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>...</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n    </tr>\n    <tr>\n      <th>901</th>\n      <td>9</td>\n      <td>H_-2_-1.55_-0.00906169.dat</td>\n      <td>-2.0</td>\n      <td>-1.55</td>\n      <td>-0.009062</td>\n      <td>0</td>\n      <td>666</td>\n      <td>train</td>\n      <td>0.100000</td>\n      <td>-0.100000</td>\n      <td>...</td>\n      <td>0.100000</td>\n      <td>-0.100000</td>\n      <td>0.100000</td>\n      <td>-0.100000</td>\n      <td>0.100000</td>\n      <td>-0.100000</td>\n      <td>0.100000</td>\n      <td>-0.100000</td>\n      <td>0.100000</td>\n      <td>-0.100000</td>\n    </tr>\n    <tr>\n      <th>902</th>\n      <td>9</td>\n      <td>H_-2_-1.55_-0.00906169.dat</td>\n      <td>-2.0</td>\n      <td>-1.55</td>\n      <td>-0.009062</td>\n      <td>0</td>\n      <td>666</td>\n      <td>train</td>\n      <td>0.141421</td>\n      <td>0.141209</td>\n      <td>...</td>\n      <td>0.114412</td>\n      <td>0.109682</td>\n      <td>0.123928</td>\n      <td>0.120007</td>\n      <td>0.131490</td>\n      <td>0.128438</td>\n      <td>0.136978</td>\n      <td>0.134844</td>\n      <td>0.140306</td>\n      <td>0.139123</td>\n    </tr>\n    <tr>\n      <th>903</th>\n      <td>9</td>\n      <td>H_-2_-1.55_-0.00906169.dat</td>\n      <td>-2.0</td>\n      <td>-1.55</td>\n      <td>-0.009062</td>\n      <td>0</td>\n      <td>666</td>\n      <td>train</td>\n      <td>0.141421</td>\n      <td>0.139516</td>\n      <td>...</td>\n      <td>-0.043702</td>\n      <td>-0.065115</td>\n      <td>0.008880</td>\n      <td>-0.014328</td>\n      <td>0.060214</td>\n      <td>0.038471</td>\n      <td>0.103092</td>\n      <td>0.085867</td>\n      <td>0.131490</td>\n      <td>0.121203</td>\n    </tr>\n    <tr>\n      <th>904</th>\n      <td>9</td>\n      <td>H_-2_-1.55_-0.00906169.dat</td>\n      <td>-2.0</td>\n      <td>-1.55</td>\n      <td>-0.009062</td>\n      <td>0</td>\n      <td>666</td>\n      <td>train</td>\n      <td>0.141421</td>\n      <td>0.140572</td>\n      <td>...</td>\n      <td>0.043702</td>\n      <td>0.028721</td>\n      <td>0.075777</td>\n      <td>0.062255</td>\n      <td>0.103092</td>\n      <td>0.091879</td>\n      <td>0.123928</td>\n      <td>0.115729</td>\n      <td>0.136978</td>\n      <td>0.132307</td>\n    </tr>\n    <tr>\n      <th>...</th>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>. ...
#      'execution_count': 9}],
#    'source': '# A view of train data\ndataframe[dataframe.type_of == "train"].head(1000)'},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:32:42.473832',
#      'end_time': '2020-03-03T02:32:42.903949',
#      'duration': 0.430117,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '      id                    path   t1   t2   winding  phase  pred_phase  \\\n0      0    H_-2_-2_0.509296.dat -2.0 -2.0  0.509296    999         666   \n1      0    H_-2_-2_0.509296.dat -2.0 -2.0  0.509296    999         666   \n2      0    H_-2_-2_0.509296.dat -2.0 -2.0  0.509296    999         666   \n3      0    H_-2_-2_0.509296.dat -2.0 -2.0  0.509296    999         666   \n4      0    H_-2_-2_0.509296.dat -2.0 -2.0  0.509296    999         666   \n...   ..                     ...  ...  ...       ...    ...         ...   \n7895  78  H_-2_1.9_0.0349338.dat -2.0  1.9  0.034934      0         666   \n7896  78  H_-2_1.9_0.0349338.dat -2.0  1.9  0.034934      0         666   \n7897  78  H_-2_1.9_0.0349338.dat -2.0  1.9  0.034934      0         666   \n7898  78  H_-2_1.9_0.0349338.dat -2.0  1.9  0.034934      0         666   \n7899  78  H_-2_1.9_0.0349338.dat -2.0  1.9  0.034934      0         666   \n\n     type_of      feat0      feat1  ...     feat90     feat91     feat92  \\\n0       test   0.100000   0.100000  ...   0.100000   0.100000   0.100000   \n1       test   0.141421   0.141142  ...   0.114412   0.108967   0.123928   \n2       test   0.141421   0.140306  ...   0.043702   0.026500   0.075777   \n3       test  -0.100000   0.100000  ...  -0.100000   0.100000  -0.100000   \n4       test   0.000509  -0.008372  ...  -0.082713  -0.089753  -0.067684   \n...      ...        ...        ...  ...        ...        ...        ...   \n7895    test  -0.141421   0.115664  ...   0.141421  -0.115664  -0.044160   \n7896    test   0.001979   0.129874  ...  -0.001979  -0.129874   0.081516   \n7897    test  -0.141421  -0.116087  ...   0.141421   0.116087  -0.043458   \n7898    test   0.000057   0.081027  ...  -0.000057  -0.081027  -0.134482   \n7899    test   0.000285  -0.081214  ...  -0.000285   0.081214  -0.134411   \n\n         feat93     feat94     feat95     feat96     feat97     feat98  \\\n0      0.100000   0.100000   0.100000   0.100000   0.100000   0.100000   \n1      0.119406   0.131490   0.127962   0.136978   0.134500   0.140306   \n2      0.060214   0.103092   0.090145   0.123928   0.114412   0.136978   \n3      0.100000  -0.100000   0.100000  -0.100000   0.100000  -0.100000   \n4     -0.075347  -0.051587  -0.059753  -0.034677  -0.043217  -0.017220   \n...         ...        ...        ...        ...        ...        ...   \n7895   0.113134  -0.114128   0.045743   0.114695  -0.141405   0.043243   \n7896  -0.137969   0.133875  -0.093364   0.135098  -0.013097   0.084718   \n7897  -0.112689  -0.114563  -0.046441   0.114261   0.141392   0.043945   \n7898  -0.085197   0.083171   0.133681   0.083079   0.002577  -0.134517   \n7899   0.085014   0.083356  -0.133755   0.082894  -0.002349  -0.134588   \n\n         feat99  \n0      0.100000  \n1      0.138916  \n2      0.131490  \n3      0.100000  \n4     -0.026000  \n...         ...  \n7895   0.041650  \n7896   0.072172  \n7897  -0.040944  \n7898  -0.135274  \n7899   0.135207  \n\n[1000 rows x 108 columns]',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>id</th>\n      <th>path</th>\n      <th>t1</th>\n      <th>t2</th>\n      <th>winding</th>\n      <th>phase</th>\n      <th>pred_phase</th>\n      <th>type_of</th>\n      <th>feat0</th>\n      <th>feat1</th>\n      <th>...</th>\n      <th>feat90</th>\n      <th>feat91</th>\n      <th>feat92</th>\n      <th>feat93</th>\n      <th>feat94</th>\n      <th>feat95</th>\n      <th>feat96</th>\n      <th>feat97</th>\n      <th>feat98</th>\n      <th>feat99</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>H_-2_-2_0.509296.dat</td>\n      <td>-2.0</td>\n      <td>-2.0</td>\n      <td>0.509296</td>\n      <td>999</td>\n      <td>666</td>\n      <td>test</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>...</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n      <td>0.100000</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>0</td>\n      <td>H_-2_-2_0.509296.dat</td>\n      <td>-2.0</td>\n      <td>-2.0</td>\n      <td>0.509296</td>\n      <td>999</td>\n      <td>666</td>\n      <td>test</td>\n      <td>0.141421</td>\n      <td>0.141142</td>\n      <td>...</td>\n      <td>0.114412</td>\n      <td>0.108967</td>\n      <td>0.123928</td>\n      <td>0.119406</td>\n      <td>0.131490</td>\n      <td>0.127962</td>\n      <td>0.136978</td>\n      <td>0.134500</td>\n      <td>0.140306</td>\n      <td>0.138916</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>0</td>\n      <td>H_-2_-2_0.509296.dat</td>\n      <td>-2.0</td>\n      <td>-2.0</td>\n      <td>0.509296</td>\n      <td>999</td>\n      <td>666</td>\n      <td>test</td>\n      <td>0.141421</td>\n      <td>0.140306</td>\n      <td>...</td>\n      <td>0.043702</td>\n      <td>0.026500</td>\n      <td>0.075777</td>\n      <td>0.060214</td>\n      <td>0.103092</td>\n      <td>0.090145</td>\n      <td>0.123928</td>\n      <td>0.114412</td>\n      <td>0.136978</td>\n      <td>0.131490</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>0</td>\n      <td>H_-2_-2_0.509296.dat</td>\n      <td>-2.0</td>\n      <td>-2.0</td>\n      <td>0.509296</td>\n      <td>999</td>\n      <td>666</td>\n      <td>test</td>\n      <td>-0.100000</td>\n      <td>0.100000</td>\n      <td>...</td>\n      <td>-0.100000</td>\n      <td>0.100000</td>\n      <td>-0.100000</td>\n      <td>0.100000</td>\n      <td>-0.100000</td>\n      <td>0.100000</td>\n      <td>-0.100000</td>\n      <td>0.100000</td>\n      <td>-0.100000</td>\n      <td>0.100000</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>0</td>\n      <td>H_-2_-2_0.509296.dat</td>\n      <td>-2.0</td>\n      <td>-2.0</td>\n      <td>0.509296</td>\n      <td>999</td>\n      <td>666</td>\n      <td>test</td>\n      <td>0.000509</td>\n      <td>-0.008372</td>\n      <td>...</td>\n      <td>-0.082713</td>\n      <td>-0.089753</td>\n      <td>-0.067684</td>\n      <td>-0.075347</td>\n      <td>-0.051587</td>\n      <td>-0.059753</td>\n      <td>-0.034677</td>\n      <td>-0.043217</td>\n      <td>-0.017220</td>\n      <td>-0.026000</td>\n    </tr>\n    <tr>\n      <th>...</th>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <td>...</td>\n      <t ...
#      'execution_count': 10}],
#    'source': '# A view of test data\ndataframe[dataframe.type_of == "test"].head(1000)'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:32:42.948507',
#      'end_time': '2020-03-03T02:32:42.989784',
#      'duration': 0.041277,
#      'status': 'completed'}},
#    'source': '#### Unique winding values'},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2020-03-03T02:32:43.030247',
#      'end_time': '2020-03-03T02:32:43.101246',
#      'duration': 0.070999,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': 'array([  0,   1, 999], dtype=int32)'},
#      'execution_count': 11}],
#    'source': 'np.unique(dataframe.phase.values)'}],
#  'metadata': {'celltoolbar': 'Tags',
#   'kernelspec': {'display_name': 'ml_top_phases',
#    'language': 'python',
#    'name': 'ml_top_phases'},
#   'language_info': {'name': 'python',
#    'version': '3.6.10',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'papermill': {'parameters': {'allowed_windings': [0, 1],
#     'epsilon': 0.01,
#     'to_csv': True,
#     'grid_folder': '/home/linneu/ssh_grids/ssh1/periodic_100_6561',
#     'csv_name': '/home/linneu/ssh_csvs/ssh1/periodic_100_6561.csv'},
#    'environment_variables': {},
#    'version': '2.0.0',
#    'input_path': 'preprocessing_template.ipynb',
#    'output_path': 'preprocessing_output.ipynb',
#    'start_time': '2020-03-03T02:30:59.781077',
#    'end_time': '2020-03-03T02:32:43.147240',
#    'duration': 103.366163,
#    'exception': None}},
#  'nbformat': 4,
#  'nbformat_minor': 2}

# %% [markdown]
# ## SSH 2

# %%
template = "preprocessing_template.ipynb"
output = "preprocessing_output.ipynb"
parameters = {"allowed_windings":[-1,0,1,2], "epsilon":0.01, "to_csv":True}
#kernel_name = "ml_top_phases"
grid_folders_and_csv_names = [("/home/linneu/ssh_grids/ssh2/periodic_100_6561", "/home/linneu/ssh_csvs/ssh2/periodic_100_6561.csv"),\
                             ("/home/linneu/ssh_grids/ssh2/periodic_140_6561", "/home/linneu/ssh_csvs/ssh2/periodic_140_6561.csv"),\
                             ("/home/linneu/ssh_grids/ssh2/periodic_180_6561", "/home/linneu/ssh_csvs/ssh2/periodic_180_6561.csv"),\
                             ("/home/linneu/ssh_grids/ssh2/periodic_220_6561", "/home/linneu/ssh_csvs/ssh2/periodic_220_6561.csv")\
                             ]
